# %% [markdown]
# # Predict biogas emitions daily to optimize the plants capacity
#
# ## Formulate the research problem
#
# Производството на биогаз от органични отпадъци е ключово за устойчивата енергетика и управление на отпадъците. Способността да се предсказва точно дневното производство на газ позволява по-добро планиране на енергийните доставки и оптимизиране на процеса на анаеробно разграждане. Този проект използва 15-годишни реални данни от биогазова инсталация в Индия, за да изгради регресионни модели, които могат да подпомогнат операторите в подобни процеси.
